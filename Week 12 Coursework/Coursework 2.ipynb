# %% [markdown]
# <h1 style="color:white;background-color:rgb(10, 57, 125);font-size:2.5rem;font-weight:bold"> <br> &nbsp; QMUL School of Mathematical Sciences <br> </h1>

# %% [markdown]
# <h1> <strong> MTH5005 Programming in Python II </strong> </h1>
# <h2> <strong> Coursework 2 <strong> </h2>
# <h3> <strong> <i> Dr Matthew Lewis </i> </strong> </h3>

# %% [markdown]
# <div style="
#   border-left: 6px solid #d9534f;
#   background-color: #fdecea;
#   padding: 16px;
#   border-radius: 6px;
#   font-size: 16px;
#   line-height: 1.5;
#   margin: 12px 0;
# ">
# <h2> Instructions </h2>
#
# <ul>
# <li> This coursework will contribute <b>30%</b> of your overall grade for this module.  The deadline for this work is <b>17:00</b> on <b>Friday 17th April 2026</b>, by which point it must be <a href="https://qmplus.qmul.ac.uk/mod/assign/view.php?id=3515161">submitted to the module's QMplus page</a>.  Once this deadline has elapsed, any submitted attempts will receive a late penalty of 5% per day, up to a maximum of seven days past the deadline.  After this point, it will no longer be possible to submit. </li><br>
#
# <li> Your final work will be a folder containing Python files.  This folder must be compressed to a single ZIP file upon submission.  To zip a folder on a Windows machine: right-click on the folder and select <samp>Compress to...</samp> from the resulting menu.  A secondary menu should pop-out, from which you can select ZIP file.  A ZIP file with the same name as the original folder should then appear in the directory.  </li><br>
#
# <li> This coursework focuses on content delivered in Weeks 5 - 8 of this module.  It is <b>open book</b>, meaning that you are free to use the lecture notes, lab workbooks, and other online resources to answer the questions. </li><br>
#
# <li> You must not, however, solicit assistance from other people, whether online or in-person.  This includes the use of messaging platforms and forums (e.g. email, Discord, WhatsApp, Chegg, Stack Exchange, etc), and you may not use generative AI. </li>
# </ul>
# </div>

# %% [markdown]
# <h2> Problem </h2>
#
# In this coursework, we will build on the concept of grids that we discussed in Coursework 1.  In that coursework, we built a file called <samp>grids.py</samp> that included a definition for a class <samp>Grid</samp>.  This class modelled grids of $n \times n$ blocks, where each block can either be vacant or occupied.  Included in that class were methods that allowed us to add and delete occupancies, giving us control over which blocks were occupied.
#
# We will extend this idea to model three specific types of grids:
#
# <ul>
#     <li><b>Uniform Grids</b>:  We say that a grid is <b>uniform</b> if each of its rows and columns has <em>exactly</em> two occupancies.</li><br>
#     <li><b>No-Three-in-Line Grids</b>: We say that a grid satisfies the <b>no-three-in-line</b> property if there are no instances of three occupancies lying in a straight line.  Note that these lines do not necessarily have to be horizontal or vertical, a straight line of <em>any</em> gradient would count.</li><br>
#     <li><b>UNTiL Grids</b>: We say that a grid is an <b>UNTiL grid</b> if it is both uniform <em>and</em> satisfies the no-three-in-line property.</li>
# </ul>
#
# As a demonstration, the following grid is neither uniform, nor satisfies the no-three-in-line property:
#
# <pre>
#     ■ ■ ■ □
#     □ □ □ ■
#     ■ □ ■ □
#     □ ■ □ ■
# </pre>
#
# The following grid is uniform, but does not satisfy the no-three-in-line property:
#
# <pre>
#     □ ■ ■ □
#     ■ □ □ ■
#     ■ □ ■ □
#     □ ■ □ ■
# </pre>
#
# The following grid is not uniform, but does satisfy the no-three-in-line property:
#
# <pre>
#     □ ■ □ ■
#     □ □ ■ □
#     ■ □ □ □
#     □ ■ □ ■
#
# </pre>
#
# The following grid is uniform, and satisfies the no-three-in-line property.  It is therefore an UNTiL grid.
#
# <pre>
#     □ ■ □ ■
#     ■ □ ■ □
#     ■ □ ■ □
#     □ ■ □ ■
# </pre>
#
# We aim to subclass <samp>Grid</samp> to model each of these more specific types of grid structures.  Much of our effort will have to go into implementing tests for uniformity and the no-three-in-line property.  If a grid fails these tests, we will have to raise an appropriate error, and so new exceptions must be constructed for these contexts.  We will construct these exceptions in a separate file and import them.
#
# We also wish to analyse the time complexity of instance construction across these classes.  We will do this by initialising instances of each class with the same occupancy data, and plotting the runtimes of each construction in a single figure.  Since these tests are independent of the class definitions, the code to run them should also be held in a separate file.
#
# In short: we will be constructing a package to model the four types of grid structure: standard, uniform, no-three-in-line, and UNTiL; giving tailor-made exceptions when an instance does not meet the required properties, and giving a test script to allow a user to compare runtimes of the initialisation routines of each class.

# %% [markdown]
# <h2> Exercises </h2>
#
# <b>For these exercises, you will require the <samp>grids.py</samp> file from Coursework 1.</b>  Sample solutions should have been provided to you, and you are free to build this coursework on top of these.  You are also welcome to use your own solutions, but please ensure that any errors have been corrected, in order that they do not propagate through the exercises below.
#
# <b>Part I.</b> Create a new folder called <samp>until</samp>, this will be the package we create throughout this coursework.  Begin by placing the <samp>grids.py</samp> file into this folder.  Before we update this file, we begin with the creation of a new file in which we will build our own exceptions.
#
# <ol>
#     <li> In the <samp>until</samp> folder, create a new file called <samp>exceptions.py</samp>.  Inside this file, create two new subclasses of the built-in <samp style="color: rgb(178, 43, 49);font-weight: bold;">Exception</samp> class.  The first new exception should be called <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp>.  Instances of this exception should accept a parameter <samp>msg</samp>, which allows us to include a specific error message when this exception is raised.<br><br>A second exception, <samp style="color: rgb(178, 43, 49);font-weight: bold;">OperatorError</samp> should be constructed with an identical definition (including a <samp>msg</samp> parameter).  Neither exception requires anything more than an <samp>__init__</samp> method. </li><p style="text-align: right;"><b>[8 marks]</b></p>
# </ol>
#
# <b>Part II.</b> Apart from the addition of some documentation, we have now finished editing the <samp>exceptions.py</samp> file.  Our next step will be updating <samp>grids.py</samp> to improve the <samp>Grid</samp> class, and create subclasses to model our new grid structures.
#
# <ol start = 2>
#     <li> Modify the definition of the <samp>Grid</samp> class so that if a user attempts to call the <samp>add_occupancy</samp> method on a box that is already occupied, an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> is raised with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Box at given coordinates already occupied.'</span>.<br><br>Similarly, the <samp>del_occupancy</samp> method should raise an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Box at given coordinates already vacant.'</span>, if the user attempts to delete a box that is not occupied.<br><br>Note that these exceptions will have to be imported from the <samp>exceptions.py</samp> file.  The class definitions of these exceptions should <b>not</b> be duplicated in <samp>grids.py</samp>.  </li><br><p style="text-align: right;"><b>[4 marks]</b></p>
#     <li> Modify the definition of the <samp>__add__</samp> method of the <samp>Grid</samp> class, so that the print-out telling users <span style="font-family:consolas;color:rgb(186,33,33);">'Error: Grids must be of matching size.'</span> is replaced with the same message raised through an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OperatorError</samp>. </li><br><p style="text-align: right;"><b>[4 marks]</b></p>
#     <li> In the <samp>Grid</samp> class, rename the <samp>get_occupancies</samp> method to <samp>occupancies</samp>, and decorate it with the built-in <samp>property</samp> decorator.  This should ensure that the <samp>_occupancies</samp> list can be obtained through the pseudo-public attribute <samp>occupancies</samp>.</li><br><p style="text-align: right;"><b>[4 marks]</b></p>
#     <li> Modify the <samp>__repr__</samp> method of the <samp>Grid</samp> class, so that instead of using the name <samp>Grid</samp> in its read-outs, it uses the name of whichever class <samp>self</samp> belongs to.<br><br>(<b>Hint:</b> The class of a given object can be returned through its <samp>__class__</samp> attribute, and all classes store their name (as a string) in their <samp>__name__</samp> attribute.) </li><br><p style="text-align: right;"><b>[6 marks]</b></p>
#     <li> In the <samp>grids.py</samp> file, define a subclass of <samp>Grid</samp> called <samp>UniformGrid</samp> to model uniform grids.  Instances of this subclass should be constructed with the same parameters and attributes as its parent class.  The key difference is that if any row or column of the grid does not have exactly two occupancies, an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> should be raised with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Each row and column must have exactly two occupancies.'</span>.  </li><br><p style="text-align: right;"><b>[10 marks]</b></p>
#     <li> Instances of <samp>UniformGrid</samp> can only have $2n$ occupancies (where $n$ is the length of each side of the grid).  We therefore do not want to allow users to add or delete occupancies to/from this subclass.<br><br>Override the <samp>add_occupancy</samp> and <samp>del_occupancy</samp> methods so that attempting to call them in this subclass raises an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OperatorError</samp> with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Cannot add/delete occupancies to instances of UniformGrid.'</span>. </li><br><p style="text-align: right;"><b>[5 marks]</b></p>
#     <li> Though we do not allow users to add/delete occupancies from the <samp>UniformGrid</samp> subclass, we should allow for some rearrangement of occupancies within an instance.<br><br>Consider that if we have two occupied boxes at coordinates $(x_1, y_1)$ and $(x_2, y_2)$, and the boxes at coordinates $(x_1, y_2)$ and $(x_2, y_1)$ are vacant, swapping the occupancies between these pairs will ensure that each row and column maintains exactly two occupancies.<br><br>Implement this operation in the <samp>UniformGrid</samp> class under the name <samp>commutator</samp>.  The operation should change the instance in-place, and should not return anything.<br><br>If either of the initial boxes are vacant, an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> should be raised with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Both input coordinates must be occupied.'</span>.  If either of the target boxes are occupied, an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> should be raised with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Both target coordinates must be vacant.'</span>. </li><br><p style="text-align: right;"><b>[10 marks]</b></p>
#     <li> In the <samp>grids.py</samp> file, define a subclass of <samp>Grid</samp> called <samp>NTiL</samp> to model grids with the no-three-in-line property.  Instances of this subclass should be constructed with the same parameters and attributes as its parent class.  The key difference is that if the occupancies of the grid do not satisfy the no-three-in-line property, an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> should be raised with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Cannot have three occupancies in a straight line.'</span>.<br><br>To verify this property, you may make use of the following function definition:<br><br>
#     <pre style="background-color: rgb(247, 247, 247);
#   color: rgb(0, 0, 0);
#   font-family: consolas;"><br>
#     <span style="color:rgb(0,128,0);font-weight:bold;">def</span> <span style="color: rgb(0, 0, 254);">til</span>(pt1, pt2, pt3):
#         <span style="font-family:consolas;color:rgb(186,33,33);">"""
#         Accept three points (as tuples of length 2) and
#         return True if they lie in a straight line,
#         False otherwise.
#         """</span>
#         <span style="color:rgb(0,128,0);font-weight:bold;">if</span> (pt1 <span style="color:rgb(170,34,255);font-weight:bold;">==</span> pt2) <span style="color:rgb(0,128,0);font-weight:bold;">or</span> (pt2 <span style="color:rgb(170,34,255);font-weight:bold;">==</span> pt3) <span style="color:rgb(0,128,0);font-weight:bold;">or</span> (pt3 <span style="color:rgb(170,34,255);font-weight:bold;">==</span> pt1):
#             <span style="color:rgb(0,128,0);font-weight:bold;">return</span> <span style="color:rgb(0,128,0);font-weight:bold;">False</span>
#         <span style="color:rgb(0,128,0);font-weight:bold;">else</span>:
#             <span style="color:rgb(0,128,0);font-weight:bold;">return</span> (pt1[<span style="color: rgb(0, 136, 0);">0</span>] <span style="color:rgb(170,34,255);font-weight:bold;">-</span> pt2[<span style="color: rgb(0, 136, 0);">0</span>])<span style="color:rgb(170,34,255);font-weight:bold;">*</span>(pt2[<span style="color: rgb(0, 136, 0);">1</span>] <span style="color:rgb(170,34,255);font-weight:bold;">-</span> pt3[<span style="color: rgb(0, 136, 0);">1</span>]) <span style="color:rgb(170,34,255);font-weight:bold;">==</span> (pt2[<span style="color: rgb(0, 136, 0);">0</span>] <span style="color:rgb(170,34,255);font-weight:bold;">-</span> pt3[<span style="color: rgb(0, 136, 0);">0</span>])<span style="color:rgb(170,34,255);font-weight:bold;">*</span>(pt1[<span style="color: rgb(0, 136, 0);">1</span>] <span style="color:rgb(170,34,255);font-weight:bold;">-</span> pt2[<span style="color: rgb(0, 136, 0);">1</span>])
#     </pre>
#     </li><br><p style="text-align: right;"><b>[10 marks]</b></p>
#     <li> Unlike the <samp>UniformGrid</samp> class, we will allow users to add and delete occupancies from a <samp>NTiL</samp> instance.  The <samp>del_occupancy</samp> method can be inherited from the parent class, since deleting an occupancy cannot invalidate the no-three-in-line property, and so no change is needed here.<br><br>We will modify the <samp>add_occupancy</samp> method however, as each new occupancy will require a new check to see that the no-three-in-line property is still valid.<br><br>Override the <samp>add_occupancy</samp> method in this class so that a test is run to check whether the no-three-in-line property still holds.  If the property would no longer be valid with this new occupancy, then it should not be added to the instance, and an <samp style="color: rgb(178, 43, 49);font-weight: bold;">OccupancyError</samp> should be raised with the message <span style="font-family:consolas;color:rgb(186,33,33);">'Cannot have three occupancies in a straight line.'</span>. </li><br><p style="text-align: right;"><b>[6 marks]</b></p>
#     <li> In the <samp>grids.py</samp> file, define a class <samp>UNTiL</samp> that subclasses both the <samp>UniformGrid</samp> and <samp>NTiL</samp> classes, with <samp>UniformGrid</samp> given priority.  This class should model UNTiL grids, that is, grids that satisfy both uniformity and the no-three-in-line properties.<br><br>Instances of this subclass should be constructed with the same parameters and attributes as its parent classes, but the checks given in both parent classes must be executed upon initialisation of a new instance (with the corresponding exceptions raised if either check fails). </li><p style="text-align: right;"><b>[8 marks]</b></p>
# </ol>
#
# <b>Part III.</b> With the exception of documenting the code, we have now finished editing the <samp>grids.py</samp> file.  We next create an <samp>\_\_init\_\_.py</samp> file for the folder, enabling <samp>until</samp> to function as a package.
#
# <ol start = 12>
#     <li> In the <samp>until</samp> folder, create a new file called <samp>__init__.py</samp>.  This file should import everything defined in the <samp>grids.py</samp> file.  However, the command<br><br>
#     <pre style="background-color: rgb(247, 247, 247);
#   color: rgb(0, 0, 0);
#   font-family: consolas;">
#     <span style="color:rgb(0,128,0);font-weight:bold;">from</span> until <span style="color:rgb(0,128,0);font-weight:bold;">import</span> <span style="color:rgb(170,34,255);font-weight:bold;">*</span></pre><br>
#     when run in the same directory as the package, should only import the <samp>Grid</samp>, <samp>UniformGrid</samp>, <samp>NTiL</samp> and <samp>UNTiL</samp> classes. </li><br><p style="text-align: right;"><b>[6 marks]</b></p>
# </ol>
#
# <b>Part IV.</b> Our next step will be to construct a new subpackage of <samp>until</samp> that allows us to test the definitions inside <samp>grids.py</samp>, while also analysing the time complexity of the initialisation routines of each class.
#
# <ol start = 13>
#     <li> In the <samp>until</samp> folder, create a new folder called <samp>tests</samp>.  You should have been provided with a file called <samp>samples.py</samp>, inside which is a definition of a list <samp>until_occupancies</samp>, which gives occupancy lists that satisfy both the uniformity and no-three-in-line properties.  Place the <samp>samples.py</samp> file inside this <samp>tests</samp> folder. </li><br><p style="text-align: right;"><b>[1 mark]</b></p>
#     <li> Inside this <samp>tests</samp> folder, define another file called <samp>__init__.py</samp>.  In this file, write code that uses the <samp>timeit</samp> function (from the <samp>timeit</samp> module of the Python Standard Library) to measure how long it takes to initialise a <samp>Grid</samp> instance for each of the ten pieces of occupancy data in the <samp>until_occupancies</samp> list in <samp>samples.py</samp>.<br><br>Each of these times should be logged in a list, and similar lists should be made for the runtime of instance construction for the <samp>UniformGrid</samp>, <samp>NTiL</samp> and <samp>UNTiL</samp> classes.<br><br>These runtime lists should then be plotted in a single figure, against the side-length $n$, with a <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.loglog.html">loglog scale</a>.  Each plot should be labelled with the name of the class, and the time complexity demonstrated (in Big-O notation in terms of parameter $n$).  These labels should be included in a <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html">legend</a> in the plot.<br><br>(<b>Note:</b>  These computations are computationally-intensive, so it is recommended that the <samp>number</samp> parameter of each <samp>timeit</samp> call be given value <samp>100</samp>.)<p style="text-align: right;"><b>[10 marks]</b></p>
#     </li>
# </ol>
#
# <b>Part V.</b> This concludes the modifications to all files and folders, and we should now have a functional package called <samp>until</samp>.  All that remains is to give the appropriate documentation.
#
# <ol start = 15>
#     <li> Document the code in each file of this package.  Include docstrings for each function, class, exception and file. </li><p style="text-align: right;"><b>[8 marks]</b></p>
# </ol>

# %% [markdown]
# <h2> Reflection </h2>
#
# If this Jupyter notebook is being run in the same directory as the <samp>until</samp> folder, then the following commands should run without error.

# %%
from until import *

x = UNTiL(n = 4, occupancies = [(0, 1), (0, 3), (1, 2), (1, 0), (2, 0), (2, 2), (3, 3), (3, 1)])
print(x)
# Out:
# □ ■ □ ■
# ■ □ ■ □
# ■ □ ■ □
# □ ■ □ ■

# %% [markdown]
# The following import statement executes the <samp>\_\_init\_\_.py</samp> file of the <samp>until.tests</samp> subpackage, and should therefore produce the plot comparing runtimes of all four class initialisation routines.

# %%
import until.tests

# %% [markdown]
# <div style="
#   border-left: 6px solid #f0ad4e;
#   background-color: #fff8e5;
#   padding: 16px;
#   border-radius: 6px;
#   font-size: 16px;
#   line-height: 1.5;
#   margin: 12px 0;
# ">
# <h2> Marking Criteria </h2>
#
# Each component of the above exercises will be marked according to the following scheme:
#
# <table style="
#   border-collapse: collapse;
#   width: 100%;
#   margin: 12px 0;
#   font-size: 15px;
# ">
#   <thead>
#     <tr style="background-color: #f2f2f2;">
#       <th style="border: 1px solid #ccc; padding: 10px; text-align: left; width: 15%;">
#         Grade Boundary
#       </th>
#       <th style="border: 1px solid #ccc; padding: 10px; text-align: left; width: 85%;">
#         Descriptors
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 10px; text-align: center;"><b>0% – 25%</b></td>
#       <td style="border: 1px solid #ccc; padding: 10px;">
#         <ul>
#             <li>Most elements of code result in a Syntax Error.  Very few inputs return data.</li>
#             <li>Any cases that do return outputs give incorrect values and/or data types.</li>
#             <li>Unused fragments of code remain throughout the file.</li>
#             <li>Code is not documented at all.</li>
#         </ul>
#       </td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 10px; text-align: center;"><b>25% – 50%</b></td>
#       <td style="border: 1px solid #ccc; padding: 10px;">
#           <ul>
#               <li>A few inputs run as expected, but many cases raise errors and exceptions.</li>
#               <li>Outputs are of the correct data type, but a fixable algorithmic error causes incorrect values.</li>
#               <li>Some redundant computations, and definitions of values and functions that are unnecessary and unused.</li>
#               <li>Code has some vague comments, but nothing that would be helpful to an end-user.</li>
#           </ul>
#       </td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 10px; text-align: center;"><b>50% – 75%</b></td>
#       <td style="border: 1px solid #ccc; padding: 10px;">
#           <ul>
#               <li>Majority of inputs return data, with only some fringe cases raising unexpected errors.</li>
#               <li>Most values returned are correct, with some minor rounding/formatting issues.</li>
#               <li>Occasional inefficiency in execution, but all components executable within reasonable timeframe.</li>
#               <li>Code is documented with docstrings, but some key details are missing.</li>
#           </ul>
#       </td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 10px; text-align: center;"><b>75% – 100%</b></td>
#       <td style="border: 1px solid #ccc; padding: 10px;">
#           <ul>
#               <li>All inputs return data, with any unavoidable user-issues flagged to raise error messages or exceptions.</li>
#               <li>All returned data has the correct value (to within specified tolerance) and is of the correct data type and format.</li>
#               <li>Computations are efficient, there is little-to-no redundancy in assignments, and all code is structured in a readable way.</li>
#               <li>Code is documented with docstrings, and all relevant attributes, parameters and outputs are specified.</li>
#           </ul>
#       </td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# <div style="
#   border-left: 6px solid #5cb85c;
#   background-color: #eaf7ea;
#   padding: 16px;
#   border-radius: 6px;
#   font-size: 16px;
#   line-height: 1.5;
#   margin: 12px 0;
# ">
# <h2> Hints & Tips </h2>
#
# <ul>
#     <li> Do not submit a Jupyter Notebook, and certainly do not submit <em>this</em> Jupyter Notebook.  You should feel free to use notebooks to test and edit code, but the final work should be arranged as a folder, named <samp>until</samp>, containing Python files and a subfolder of Python files.  To submit your work, the whole <samp>until</samp> folder must be compressed into a single ZIP file.</li><br>
#     <li> On a Windows machine, a folder can be compressed to a ZIP file by right-clicking on the name of the folder and selecting <samp>Compress to...</samp> from the resulting menu.  A secondary menu will pop-out, from which you can select ZIP file.  A ZIP file with the same name as the original folder will then appear in the directory. </li><br>
#     <li> To create an individual Python file in JupyterLab, open a new <samp>Launcher</samp> tab and click the <samp>Python File</samp> tile in the new window.  Pressing <kbd>Ctrl + S</kbd> to save will allow you to give the file a new name. </li><br>
#     <li> To test the code inside a Python file, you should consider running it in a terminal.  A terminal can be opened by clicking the <samp>Terminal</samp> tile in the <samp>Launcher</samp> window.  If your active terminal is open in the same directory as your file, then the file can be run with the instruction <code>python ...</code> (or <code>python -i ...</code>, if you wish to open an interactive console after execution).</li><br>
#     <li> Do not worry if you are struggling to write a method.  It may be better to test your code outside of a class first, before folding it into the class as a new method.  For example, you could test any method that affects the <samp>_occupancies</samp> attribute by applying your code to some list that <em>represents</em> <samp>_occupancies</samp>, rather than wasting time re-running code and initialising new instances every few minutes. </li><br>
#     <li> As stated above, some of the marks for this coursework are given on the basis of documentation.  Please ensure that your code is fully documented before submission.  It may be worth doing this last however, just in case you decide to change any of the functionality of the code before the final draft. </li>
# </ul>
# </div>

# %% [markdown]
# <h2> Submission </h2>
#
# Submit your zipped <samp>until</samp> package to the <a href="https://qmplus.qmul.ac.uk/mod/assign/view.php?id=3515161">Coursework 2 Submission</a> activity on the module's QMplus page by <b>17:00</b> on <b>Friday 17th April 2026</b>.  Feedback should be returned to you within two weeks of this date.  If you have any problems or questions about this coursework, you should email the lecturer for assistance at <a href="matthew.lewis@qmul.ac.uk">matthew.lewis@qmul.ac.uk</a>.
#
# <b><em>Best of luck with your work!</em></b>
